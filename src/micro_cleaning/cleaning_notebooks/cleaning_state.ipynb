# %%
import pandas as pd
import re
import numpy as np

# %%
loc = ['CASE_STATUS', 'CASE_SUBMITTED', 'EMPLOYER_CITY', 'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE', 'WORKSITE_CITY','WORKSITE_STATE', 'WORKSITE_POSTAL_CODE']

# %%
data =pd.read_csv('clean/all_clean_data.csv',usecols = loc, dtype = str)

# %%
state_values = ['TX', 'MA', 'MI', 'CA', 'VA', 'NJ', 'NY', 'PA', 'FL', 'MN', 'IL',
       'MD', 'CT', 'WA', 'IA', 'CO', 'AZ', 'GA', 'OK', 'LA', 'WI', 'ND',
       'UT', 'IN', 'OH', 'KY', 'NC', 'NH', 'MO', 'TN', 'ID', 'VT', 'DC',
       'SD', 'AL', 'OR', 'AR', 'NM', 'SC', 'NE', 'DE', 'WY', 'HI', 'KS',
       'WV', 'ME', 'RI', 'NV', 'MS', 'AK','MT','PR','GU','VI']

# %%
import zipcode
from pyzipcode import ZipCodeDatabase

# %%
def update_fix_states(x):
    if pd.isnull(x['EMPLOYER_STATE']):
        if x.EMPLOYER_POSTAL_CODE:
            newzip = zipcode.isequal(x.EMPLOYER_POSTAL_CODE)
            if newzip is not None:
                print("Old state was",x.EMPLOYER_STATE,"and new state is",newzip.state)
                return newzip.state
            else:
                return x.EMPLOYER_STATE
    elif x['EMPLOYER_STATE'] not in state_values and x.EMPLOYER_POSTAL_CODE.isdigit():
        newzip = zipcode.isequal(x.EMPLOYER_POSTAL_CODE)
        if newzip is not None:
            print("Old state was",x.EMPLOYER_STATE,"and new state is",newzip.state)
            return newzip.state
        else:
            return x.EMPLOYER_STATE
    else:
        return x.EMPLOYER_STATE

def worksite_fix_states(x):
    if pd.isnull(x['WORKSITE_STATE']):
        if x.WORKSITE_POSTAL_CODE:
            newzip = zipcode.isequal(x.WORKSITE_POSTAL_CODE)
            if newzip is not None:
                print("Old state was",x.WORKSITE_STATE,"and new state is",newzip.state)
                return newzip.state
            else:
                return x.WORKSITE_STATE
    elif x['WORKSITE_STATE'] not in state_values and x.WORKSITE_POSTAL_CODE.isdigit():
        newzip = zipcode.isequal(x.WORKSITE_POSTAL_CODE)
        if newzip is not None:
            print("Old state was",x.WORKSITE_STATE,"and new state is",newzip.state)
            return newzip.state
        else:
            return x.WORKSITE_STATE
    else:
        return x.WORKSITE_STATE

# %%
data.EMPLOYER_POSTAL_CODE =data.EMPLOYER_POSTAL_CODE.fillna('')

# %%
data.EMPLOYER_STATE = data.apply(update_fix_states,axis =1)
# Out:
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is NY
# Old state was nan and new state is FL
# Old state was nan and new state is HI
# Old state was nan and new state is MN
# Old state was AP and new state is AR
# Old state was nan and new state is CA
# Old state was IX and new state is TX
# Old state was FI and new state is FL
# Old state was nan and new state is CT
# Old state was NI and new state is NJ
# Old state was NB and new state is NE
# Old state was nan and new state is NV
# Old state was II and new state is IN
# Old state was nan and new state is NJ
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is HI
# Old state was nan and new state is CA
# Old state was nan and new state is HI
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was FI and new state is FL
# Old state was AJ and new state is NJ
# Old state was TA and new state is TX
# Old state was nan and new state is CA
# Old state was nan and new state is UT
# Old state was NT and new state is NJ
# Old state was FT and new state is FL
# Old state was FT and new state is FL
# Old state was II and new state is IN
# Old state was IX and new state is TX
# Old state was II and new state is IN
# Old state was IT and new state is FL
# Old state was II and new state is IN
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was II and new state is IN
# Old state was TI and new state is TX
# Old state was FI and new state is FL
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is MO
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was II and new state is IN
# Old state was TI and new state is TX
# Old state was II and new state is IN
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was II and new state is IN
# Old state was TI and new state is TX
# Old state was II and new state is IN
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was NT and new state is NJ
# Old state was FI and new state is FL
# Old state was nan and new state is UT
# Old state was KE and new state is ME
# Old state was JL and new state is FL
# Old state was II and new state is IN
# Old state was nan and new state is CT
# Old state was nan and new state is CT
# Old state was FI and new state is FL
# Old state was OA and new state is OR
# Old state was nan and new state is MN
# Old state was TI and new state is TN
# Old state was IX and new state is TX
# Old state was nan and new state is OH
# Old state was II and new state is IN
# Old state was nan and new state is CA
# Old state was FI and new state is FL
# Old state was nan and new state is MA
# Old state was nan and new state is CA
# Old state was nan and new state is UT
# Old state was nan and new state is NY
# Old state was nan and new state is NY
# Old state was nan and new state is CO
# Old state was NI and new state is NJ
# Old state was nan and new state is MN
# Old state was nan and new state is NY
# Old state was MY and new state is NY
# Old state was FI and new state is FL
# Old state was QH and new state is OH
# Old state was nan and new state is MA
# Old state was II and new state is IN
# Old state was II and new state is NY
# Old state was nan and new state is PA
# Old state was nan and new state is CA
# Old state was nan and new state is MO
# Old state was TA and new state is TX
# Old state was nan and new state is CA
# Old state was NI and new state is NJ
# Old state was II and new state is NY
# Old state was II and new state is IN
# Old state was nan and new state is NJ
# Old state was AY and new state is NY
# Old state was IF and new state is FL
# Old state was PI and new state is PA
# Old state was NT and new state is NJ
# Old state was FI and new state is FL
# Old state was II and new state is IN
# Old state was AI and new state is HI
# Old state was II and new state is IN
# Old state was II and new state is IN
# Old state was II and new state is IN
# Old state was nan and new state is NJ
# Old state was II and new state is IN
# Old state was FI and new state is FL
# Old state was TA and new state is IA
# Old state was IX and new state is TX
# Old state was FI and new state is FL
# Old state was NT and new state is NJ
# Old state was FI and new state is FL
# Old state was nan and new state is MO
# Old state was nan and new state is HI
# Old state was nan and new state is HI
# Old state was nan and new state is HI
# Old state was nan and new state is CA
# Old state was AV and new state is NY
# Old state was II and new state is IN
# Old state was nan and new state is NY
# Old state was nan and new state is CA
# Old state was WH and new state is NH
# Old state was nan and new state is CA
# Old state was II and new state is IN
# Old state was FI and new state is FL
# Old state was nan and new state is WA
# Old state was AI and new state is HI
# Old state was II and new state is IN
# Old state was IO and new state is IA
# Old state was FT and new state is FL
# Old state was nan and new state is MA
# Old state was nan and new state is MA
# Old state was FI and new state is FL
# Old state was NT and new state is NJ
# Old state was nan and new state is CA
# Old state was II and new state is IN
# Old state was IO and new state is IA
# Old state was nan and new state is MA
# Old state was NI and new state is NE
# Old state was nan and new state is NY
# Old state was II and new state is IN
# Old state was FI and new state is FL
# Old state was nan and new state is CA
# Old state was FI and new state is FL
# Old state was nan and new state is FL
# Old state was nan and new state is NY
# Old state was II and new state is IN
# Old state was nan and new state is NY
# Old state was FI and new state is FL
# Old state was AI and new state is NJ
# Old state was nan and new state is CA
# Old state was nan and new state is FL
# Old state was TY and new state is TX
# Old state was II and new state is IN
# Old state was NT and new state is NJ
# Old state was TK and new state is TX
# Old state was nan and new state is IN
# Old state was QA and new state is CA
# Old state was IX and new state is TX
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was FI and new state is FL
# Old state was TA and new state is IA
# Old state was nan and new state is CA
# Old state was PL and new state is AL
# Old state was QH and new state is OH
# Old state was nan and new state is NY
# Old state was nan and new state is NY
# Old state was nan and new state is NY
# Old state was nan and new state is NJ
# Old state was II and new state is IN
# Old state was nan and new state is IN
# Old state was CI and new state is CA
# Old state was II and new state is NJ
# Old state was PN and new state is PA
# Old state was NT and new state is NJ
# Old state was nan and new state is IN
# Old state was SE and new state is FL
# Old state was SE and new state is FL
# Old state was nan and new state is MN
# Old state was nan and new state is IN
# Old state was nan and new state is MA
# Old state was nan and new state is CA
# Old state was MP and new state is OH
# Old state was OO and new state is PA
# Old state was FI and new state is FL
# Old state was II and new state is FL
# Old state was TA and new state is IN
# Old state was AT and new state is NJ
# Old state was nan and new state is FL
# Old state was IX and new state is TX
# Old state was QA and new state is CA
# Old state was CI and new state is CA
# Old state was AI and new state is NY
# Old state was nan and new state is NY
# Old state was NT and new state is NJ
# Old state was nan and new state is MO
# Old state was LO and new state is LA
# Old state was TE and new state is TX
# Old state was PH and new state is PA
# Old state was TE and new state is TX
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was RA and new state is PA
# Old state was QA and new state is CA
# Old state was CI and new state is CA
# Old state was NT and new state is NJ
# Old state was nan and new state is MO
# Old state was LO and new state is LA
# Old state was AI and new state is NY
# Old state was II and new state is IN
# Old state was nan and new state is CA
# Old state was II and new state is NH
# Old state was nan and new state is MA
# Old state was IX and new state is TX
# Old state was II and new state is MA
# Old state was nan and new state is NY
# Old state was nan and new state is MA
# Old state was AY and new state is NY
# Old state was II and new state is IN
# Old state was FI and new state is FL
# Old state was QH and new state is OH
# Old state was AI and new state is AZ
# Old state was NT and new state is NJ
# Old state was II and new state is IN
# Old state was AI and new state is AZ
# Old state was IV and new state is NJ
# Old state was nan and new state is CA
# Old state was II and new state is IN
# Old state was IY and new state is NY
# Old state was nan and new state is IN
# Old state was nan and new state is MA
# Old state was II and new state is IN
# Old state was II and new state is IN
# Old state was FI and new state is FL
# Old state was nan and new state is MN
# Old state was nan and new state is FL
# Old state was nan and new state is NY
# Old state was nan and new state is CA
# Old state was nan and new state is NY
# Old state was nan and new state is NY
# Old state was LO and new state is LA
# Old state was TE and new state is TX
# Old state was II and new state is IN
# Old state was FM and new state is FL
# Old state was QK and new state is OK
# Old state was AY and new state is NY
# Old state was nan and new state is IN
# Old state was SE and new state is FL
# Old state was II and new state is IN
# Old state was nan and new state is OH
# Old state was PL and new state is FL
# Old state was CI and new state is CA
# Old state was IV and new state is NY
# Old state was PH and new state is PA
# Old state was AY and new state is NY
# Old state was TK and new state is TX
# Old state was II and new state is IN
# Old state was nan and new state is MA
# Old state was AP and new state is AR
# Old state was nan and new state is AZ
# Old state was FI and new state is FL
# Old state was nan and new state is CA
# Old state was nan and new state is LA
# Old state was nan and new state is MA
# Old state was NT and new state is NJ
# Old state was LT and new state is UT
# Old state was NI and new state is NY
# Old state was HA and new state is HI
# Old state was nan and new state is CT
# Old state was FI and new state is FL
# Old state was FI and new state is FL
# Old state was nan and new state is CA
# Old state was nan and new state is NY
# Old state was nan and new state is NJ
# Old state was nan and new state is MN
# Old state was nan and new state is NY
# Old state was FT and new state is FL
# Old state was SE and new state is FL
# Old state was IT and new state is NJ
# Old state was FI and new state is FL
# Old state was MH and new state is MA
# Old state was IX and new state is TX
# Old state was nan and new state is NJ
# Old state was nan and new state is NY
# Old state was SE and new state is FL
# Old state was SE and new state is FL
# Old state was nan and new state is NY
# Old state was nan and new state is RI
# Old state was nan and new state is CA
# Old state was NI and new state is NJ
# Old state was CI and new state is CA
# Old state was nan and new state is CA
# Old state was IJ and new state is NJ
# Old state was nan and new state is CA
# Old state was nan and new state is NY
# Old state was NI and new state is NJ
# Old state was PL and new state is FL
# Old state was II and new state is IN
# Old state was FI and new state is FL
# Old state was FJ and new state is FL
# Old state was HA and new state is HI
# Old state was nan and new state is NY
# Old state was PL and new state is FL
# Old state was II and new state is PA
# Old state was SE and new state is FL
# Old state was IT and new state is KY
# Old state was II and new state is IA
# Old state was TI and new state is TX
# Old state was II and new state is IN
# Old state was TE and new state is TX
# Old state was SE and new state is FL
# Old state was nan and new state is IN
# Old state was nan and new state is CA
# Old state was SE and new state is FL
# Old state was SE and new state is FL
# Old state was SE and new state is FL
# Old state was nan and new state is WV
# Old state was nan and new state is FL
# Old state was KA and new state is MA
# Old state was nan and new state is CA
# Old state was nan and new state is WV
# Old state was nan and new state is IN
# Old state was nan and new state is NJ
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is WA
# Old state was nan and new state is NY
# Old state was nan and new state is WY
# Old state was nan and new state is MN
# Old state was nan and new state is CA
# Old state was nan and new state is NY
# Old state was nan and new state is MA
# Old state was PE and new state is PA
# Old state was nan and new state is IN
# Old state was PE and new state is PA
# Old state was nan and new state is CA
# Old state was nan and new state is NY
# Old state was FM and new state is FL
# Old state was nan and new state is NJ
# Old state was nan and new state is PR
# Old state was nan and new state is MA
# Old state was nan and new state is NJ
# Old state was UI and new state is UT
# Old state was nan and new state is NY
# Old state was FM and new state is FL
# Old state was nan and new state is NJ
# Old state was nan and new state is CA
# Old state was LO and new state is LA
# Old state was nan and new state is NJ
# Old state was nan and new state is IN
# Old state was nan and new state is CA
# Old state was TE and new state is TX
# Old state was nan and new state is CA
# Old state was nan and new state is NJ
# Old state was nan and new state is GU
# Old state was FM and new state is FL
# Old state was nan and new state is TN
# Old state was FM and new state is FL
# Old state was nan and new state is TN
# Old state was nan and new state is CA
# Old state was nan and new state is CT
# Old state was nan and new state is NY
# Old state was nan and new state is TX
# Old state was TE and new state is TX
# Old state was nan and new state is CA
# Old state was nan and new state is NY
# Old state was nan and new state is AZ
# Old state was nan and new state is AZ
# Old state was nan and new state is FL
# Old state was TE and new state is TN
# Old state was nan and new state is NY
# Old state was nan and new state is NJ
# Old state was nan and new state is ME
# Old state was nan and new state is CA
# Old state was nan and new state is NJ
# Old state was nan and new state is FL
# Old state was AS and new state is AR
# Old state was nan and new state is NY
# Old state was IO and new state is IA
# Old state was TE and new state is TX
# Old state was nan and new state is CA
# Old state was nan and new state is TN
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was FM and new state is FL
# Old state was MP and new state is OH
# Old state was nan and new state is NH
# Old state was MP and new state is OH
# Old state was MP and new state is OH
# Old state was TE and new state is TX
# Old state was TE and new state is TX
# Old state was nan and new state is CA
# Old state was HN and new state is NH
# Old state was GE and new state is GA
# Old state was nan and new state is FL
# Old state was nan and new state is NJ
# Old state was TE and new state is TX
# Old state was nan and new state is NJ
# Old state was nan and new state is FL
# Old state was OO and new state is FL
# Old state was nan and new state is MA
# Old state was nan and new state is CA
# Old state was nan and new state is IN
# Old state was VV and new state is WV
# Old state was NT and new state is VI
# Old state was FI and new state is FL
# Old state was FI and new state is FL
# Old state was nan and new state is IN
# Old state was SE and new state is FL
# Old state was SE and new state is FL
# Old state was SE and new state is FL
# Old state was AY and new state is NY
# Old state was II and new state is IA
# Old state was nan and new state is NY
# Old state was nan and new state is IN
# Old state was TE and new state is TX
# Old state was nan and new state is CA
# Old state was nan and new state is WA
# Old state was nan and new state is NY
# Old state was nan and new state is HI
# Old state was TI and new state is TX
# Old state was nan and new state is HI
# Old state was nan and new state is MA
# Old state was nan and new state is HI
# Old state was nan and new state is CA
# Old state was nan and new state is FL
# Old state was nan and new state is CA
# Old state was NI and new state is NJ
# Old state was AT and new state is NJ
# Old state was II and new state is RI
# Old state was nan and new state is CA
# Old state was nan and new state is OR
# Old state was nan and new state is HI
# Old state was nan and new state is FL
# Old state was nan and new state is CA
# Old state was AY and new state is NY
# Old state was nan and new state is HI
# Old state was nan and new state is UT
# Old state was nan and new state is NY
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is MA
# Old state was nan and new state is NJ
# Old state was nan and new state is NJ
# Old state was nan and new state is NJ
# Old state was nan and new state is CT
# Old state was nan and new state is CT
# Old state was nan and new state is CA
# Old state was nan and new state is NY
# Old state was nan and new state is NY
# Old state was nan and new state is OH
# Old state was nan and new state is MA
# Old state was nan and new state is NY
# Old state was PH and new state is OH
# Old state was nan and new state is MA
# Old state was nan and new state is IN
# Old state was nan and new state is FL
# Old state was nan and new state is TN
# Old state was FM and new state is FL
# Old state was nan and new state is NY
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was TE and new state is TX
# Old state was TE and new state is TX
# Old state was FT and new state is FL
# Old state was NI and new state is NJ
# Old state was NI and new state is NY
# Old state was nan and new state is NY
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is OR
# Old state was nan and new state is MN
# Old state was HA and new state is HI
# Old state was nan and new state is FL
# Old state was nan and new state is MN
# Old state was QH and new state is OH
# Old state was TA and new state is TX
# Old state was IX and new state is TX
# Old state was II and new state is IN
# Old state was NI and new state is NJ
# Old state was nan and new state is NY
# Old state was PE and new state is PA
# Old state was nan and new state is FL
# Old state was nan and new state is CA
# Old state was nan and new state is NY
# Old state was nan and new state is CA
# Old state was nan and new state is CT
# Old state was nan and new state is WA
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is NJ
# Old state was FM and new state is FL
# Old state was nan and new state is HI
# Old state was nan and new state is NY
# Old state was nan and new state is GA
# Old state was nan and new state is IA
# Old state was nan and new state is TX
# Old state was nan and new state is NY
# Old state was nan and new state is CA
# Old state was nan and new state is IA
# Old state was OO and new state is FL
# Old state was nan and new state is NJ
# Old state was nan and new state is NJ
# Old state was nan and new state is CA
# Old state was nan and new state is FL
# Old state was FM and new state is FL
# Old state was FM and new state is FL
# Old state was AS and new state is AZ
# Old state was MP and new state is MO
# Old state was FM and new state is FL
# Old state was FM and new state is FL
# Old state was nan and new state is KS
# Old state was PE and new state is PA
# Old state was nan and new state is NJ
# Old state was nan and new state is TX
# Old state was KE and new state is KY
# Old state was nan and new state is NJ
# Old state was nan and new state is NJ
# Old state was nan and new state is CA
# Old state was nan and new state is NJ
# Old state was nan and new state is NJ
# Old state was nan and new state is NY
# Old state was nan and new state is NY
# Old state was nan and new state is NY
# Old state was VE and new state is VT
# Old state was nan and new state is NY
# Old state was  G and new state is GA
# Old state was IO and new state is IA
# Old state was nan and new state is FL
# Old state was nan and new state is OH
# Old state was TE and new state is TX
# Old state was TE and new state is TX
# Old state was TE and new state is TX
# Old state was nan and new state is KY
# Old state was PE and new state is PA
# Old state was nan and new state is NY
# Old state was nan and new state is CT
# Old state was nan and new state is CT
# Old state was nan and new state is FL
# Old state was TE and new state is TX
# Old state was KA and new state is KS
# Old state was nan and new state is TX
# Old state was nan and new state is TX
# Old state was nan and new state is TX
# Old state was nan and new state is CA
# Old state was nan and new state is TX
# Old state was TU and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is IN
# Old state was TE and new state is TX
# Old state was nan and new state is CA
# Old state was nan and new state is FL
# Old state was nan and new state is CA
# Old state was IO and new state is IA
# Old state was nan and new state is CA
# Old state was nan and new state is NY
# Old state was TE and new state is TX
# Old state was nan and new state is TX
# Old state was nan and new state is KS
# Old state was TE and new state is TX
# Old state was nan and new state is IN
# Old state was nan and new state is IN
# Old state was nan and new state is IN
# Old state was nan and new state is IN
# Old state was nan and new state is IN
# Old state was nan and new state is TX
# Old state was nan and new state is OR
# Old state was TE and new state is TX
# Old state was nan and new state is CA
# Old state was nan and new state is TX
# Old state was LO and new state is LA
# Old state was nan and new state is CA
# Old state was TE and new state is TX
# Old state was TE and new state is TX
# Old state was TE and new state is TX
# Old state was nan and new state is OR
# Old state was NO and new state is ND
# Old state was nan and new state is CA
# Old state was KE and new state is KY
# Old state was nan and new state is TX
# Old state was nan and new state is FL
# Old state was KE and new state is KY
# Old state was nan and new state is OK
# Old state was IO and new state is IA
# Old state was TE and new state is TX
# Old state was  N and new state is NJ
# Old state was TE and new state is TX
# Old state was SE and new state is AZ
# Old state was IO and new state is IA
# Old state was  N and new state is NJ
# Old state was nan and new state is FL
# Old state was SE and new state is AZ
# Old state was IO and new state is IA
# Old state was nan and new state is NY
# Old state was nan and new state is NY
# Old state was GE and new state is GA
# Old state was AS and new state is AZ
# Old state was TE and new state is TX
# Old state was CN and new state is CT
# Old state was nan and new state is FL
# Old state was nan and new state is NY
# Old state was IO and new state is IA
# Old state was nan and new state is TX
# Old state was nan and new state is NY
# Old state was FM and new state is FL
# Old state was IO and new state is IA
# Old state was nan and new state is FL
# Old state was CN and new state is CT
# Old state was CN and new state is CT
# Old state was nan and new state is NY
# Old state was CN and new state is CT
# Old state was CN and new state is CT
# Old state was PP and new state is PA
# Old state was nan and new state is TX
# Old state was FM and new state is FL
# Old state was nan and new state is CT
# Old state was nan and new state is NY
# Old state was nan and new state is CT
# Old state was nan and new state is CT
# Old state was  T and new state is TX
# Old state was nan and new state is NY
# Old state was N and new state is NY
# Old state was nan and new state is FL
# Old state was nan and new state is FL
# Old state was TF and new state is TX
# Old state was nan and new state is OH
# Old state was nan and new state is WA
# Old state was KE and new state is KY
# Old state was nan and new state is NY
# Old state was nan and new state is PA
# Old state was nan and new state is MS
# Old state was nan and new state is CA
# Old state was nan and new state is FL
# Old state was nan and new state is FL
# Old state was nan and new state is OH
# Old state was HA and new state is HI
# Old state was TE and new state is TX
# Old state was nan and new state is FL
# Old state was  N and new state is NY
# Old state was  N and new state is NY
# Old state was  N and new state is NY
# Old state was  N and new state is NY
# Old state was  N and new state is NY
# Old state was nan and new state is NY
# Old state was nan and new state is CA
# Old state was nan and new state is OK
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is IN
# Old state was nan and new state is CA
# Old state was nan and new state is OH
# Old state was nan and new state is CO
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was FM and new state is HI
# Old state was FM and new state is FL
# Old state was MH and new state is MA
# Old state was nan and new state is NJ
# Old state was N and new state is NY
# Old state was nan and new state is WV
# Old state was TE and new state is TX
# Old state was TE and new state is TX
# Old state was TE and new state is PA
# Old state was nan and new state is MA
# Old state was TE and new state is TX
# Old state was SE and new state is FL
# Old state was SE and new state is FL
# Old state was HA and new state is HI
# Old state was nan and new state is TX
# Old state was nan and new state is FL
# Old state was nan and new state is NJ
# Old state was nan and new state is VI
# Old state was PE and new state is PA
# Old state was nan and new state is TX
# Old state was YO and new state is NY
# Old state was KE and new state is KS
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was nan and new state is FL
# Old state was nan and new state is CA
# Old state was TE and new state is TX
# Old state was nan and new state is TX
# Old state was nan and new state is CA
# Old state was nan and new state is NY
# Old state was PE and new state is PA
# Old state was SE and new state is NY
# Old state was nan and new state is ND
# Old state was nan and new state is ND
# Old state was TE and new state is TX
# Old state was PW and new state is NY
# Old state was FM and new state is FL
# Old state was MH and new state is MN
# Old state was PW and new state is PR
# Old state was FM and new state is FL
# Old state was MH and new state is MA
# Old state was MH and new state is MA
# Old state was AS and new state is CA
# Old state was MP and new state is MO
# Old state was nan and new state is NJ
# Old state was nan and new state is MN
# Old state was nan and new state is IN
# Old state was  N and new state is IN
# Old state was nan and new state is NY
# Old state was nan and new state is CA
# Old state was VE and new state is VT
# Old state was nan and new state is NY
# Old state was nan and new state is TX
# Old state was FF and new state is FL
# Old state was GE and new state is GA
# Old state was GE and new state is GA
# Old state was nan and new state is NJ
# Old state was nan and new state is NM
# Old state was nan and new state is TX
# Old state was SE and new state is FL
# Old state was nan and new state is CT
# Old state was nan and new state is NY
# Old state was  N and new state is NJ
# Old state was  N and new state is NJ
# Old state was  N and new state is NY
# Old state was  N and new state is NY
# Old state was TE and new state is TX
# Old state was TE and new state is TX
# Old state was LO and new state is LA
# Old state was TE and new state is TX
# Old state was VE and new state is VT
# Old state was  I and new state is IN
# Old state was nan and new state is TX
# Old state was TE and new state is TX
# Old state was  N and new state is NJ
# Old state was US and new state is VI
# Old state was FM and new state is FL
# Old state was FM and new state is FL
# Old state was nan and new state is CA
# Old state was SO and new state is SD
# Old state was TE and new state is TX
# Old state was AS and new state is AK
# Old state was nan and new state is WA
# Old state was nan and new state is CA
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is CA
# Old state was MP and new state is CA
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is CA
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is CA
# Old state was nan and new state is GA
# Old state was nan and new state is CA
# Old state was FM and new state is FL
# Old state was AS and new state is AZ
# Old state was AS and new state is AZ
# Old state was AS and new state is CA
# Old state was AS and new state is CA
# Old state was AS and new state is CA
# Old state was AS and new state is CA
# Old state was AS and new state is CA
# Old state was AS and new state is CA
# Old state was AS and new state is CA
# Old state was AS and new state is CA
# Old state was FM and new state is FL
# Old state was MP and new state is MP
# Old state was nan and new state is OK
# Old state was MP and new state is MP
# Old state was nan and new state is LA
# Old state was nan and new state is ME
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is ME
# Old state was MP and new state is MP
# ...
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is NY
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is GU
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is OH
# Old state was nan and new state is GA
# Old state was nan and new state is CA
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was PW and new state is TX
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is TX
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is NJ
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is FL
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is TX
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is TX
# Old state was MP and new state is MP
# Old state was nan and new state is CA
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is NJ
# Old state was FM and new state is FL
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was FM and new state is FL
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is NY
# Old state was nan and new state is NY
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is NJ
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is CA
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is FL
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is CA
# Old state was nan and new state is CA
# Old state was MP and new state is MP
# Old state was nan and new state is CA
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was nan and new state is NY
# Old state was nan and new state is NY
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP

# %%
data.EMPLOYER_STATE.unique()
# Out:
# array(['CA', 'PA', 'NY', 'MI', 'TX', 'MA', 'IL', 'GA', 'NJ', 'CO', 'VA',
#        'MO', 'CT', 'NM', 'MD', 'WA', 'NC', 'FL', 'AL', 'SC', 'PR', 'GU',
#        'NE', 'NH', 'OR', 'OH', 'IN', 'TN', 'MN', 'WI', 'OK', 'KY', 'DE',
#        'NV', 'IA', 'HI', 'MS', 'AZ', 'VT', 'LA', 'DC', 'ID', 'UT', 'AR',
#        'KS', 'AK', 'SD', 'ME', None, 'WV', 'DL', 'RI', 'ND', 'II', 'IF',
#        nan, 'MT', 'VI', 'MP', 'WY', 'PI', 'AI', 'TL', 'IZ', 'CI', 'I',
#        'AY', 'LI', 'CJ', 'GP', 'QI', 'NG', 'WT', 'TA', 'GE', 'JA', 'IC',
#        'LO', 'QA', 'JL', 'HD', 'AT', 'NO', 'UK', 'SO', 'D', 'FM', 'L',
#        'HA', 'TV', 'OA', 'MH', 'M', 'KA', 'TI', 'ON', 'SE', 'FE', ' M',
#        ' C', 'DN', 'KE', 'US', 'TS', 'AS', 'VY', 'A COURTYARD BY MARRIOTT'], dtype=object)

# %%
val = ['TX', 'MA', 'MI', 'CA', 'VA', 'NJ', 'NY', 'PA', 'FL', 'MN', 'IL',
       'MD', 'CT', 'WA', 'IA', 'CO', 'AZ', 'GA', 'OK', 'LA', 'WI', 'ND',
       'UT', 'IN', 'OH', 'KY', 'NC', 'NH', 'MO', 'TN', 'ID', 'VT', 'DC',
       'SD', 'AL', 'OR', 'AR', 'NM', 'SC', 'NE', 'DE', 'WY', 'HI', 'KS',
       'WV', 'ME', 'RI', 'NV', 'MS', 'AK','MT', 'PR', 'GU', 'VI',  'MP', 'AS']

data['EMPLOYER_STATE'] = [
    i if i in val else np.nan for i in data['EMPLOYER_STATE']
]

# %%
data.EMPLOYER_STATE.isnull().sum()
# Out:
# 1599

# %%
data.WORKSITE_POSTAL_CODE =data.WORKSITE_POSTAL_CODE.fillna('')

# %%
data.WORKSITE_STATE = data.apply(worksite_fix_states,axis =1)
# Out:
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is CA
# Old state was MP and new state is CA
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is NY
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP
# Old state was MP and new state is MP

# %%
data.WORKSITE_STATE.unique()
# Out:
# array(['CA', 'NY', 'MS', 'PR', 'PA', 'OH', 'OK', 'OR', 'MD', 'DE', 'FL',
#        'TX', 'VA', 'MA', 'IL', 'IA', 'NJ', 'CO', 'MO', 'MN', 'NC', 'UT',
#        'AK', 'VT', 'MI', 'CT', 'WI', 'KS', 'NE', 'WA', 'GA', 'TN', 'WV',
#        'DC', 'AZ', 'KY', 'AL', 'SC', 'LA', 'IN', 'NH', 'GU', 'NM', 'ID',
#        'AR', 'ND', 'ME', None, 'FI', 'HI', 'SD', 'RI', 'NV', 'OC', 'II',
#        'MT', 'NN', 'TA', 'A', 'QH', 'NI', 'AI', 'FT', 'I', 'NB', 'NT', 'S',
#        'IY', 'L', ' A', 'WY', 'DF', 'A8', 'TL', 'O', 'Y', 'IX', 'XL', 'PI',
#        'OO', 'KI', 'MF', 'IC', 'PL', 'X', 'F', 'N', 'AY', 'CI', 'RJ', 'TY',
#        'OA', 'AE', 'IO', 'IT', 'AA', 'VI', 'CK', 'TI', 'AN', ' I', 'WH',
#        'IV', 'PC', 'PN', 'NO', 'IE', 'YA', 'CF', 'AS', 'QA', 'AT', 'IM',
#        'E', 'OZ', 'JE', 'RD', 'H', 'C0', 'LT', 'CH', 'NG', 'R', 'HA', 'SL',
#        'T', 'QK', 'TV', 'M', 'D', 'IZ', 'MH', 'VR', 'VL', 'MJ', 'UI', 'WM',
#        'CL', 'ML', 'CN', 'LO', 'LU', 'IS', 'MU', 'FM', 'V', 'C', 'J', 'AF',
#        'US', ' M', ' C', 'GG', ' F', 'G', 'SO', 'PH', 'W', 'MP', nan,
#        'ST. HELENS', 'TRENTON', 'MOUNTAIN LAKE', '7 EVERETT LN',
#        'PORT TOBACCO', 'BALTIMORE', 'CRAWFORD & CLARE COS', 'SAN ANTONIO',
#        'CHARLESTON', 'FREMONT', 'CEDAR RAPIDS', 'SANTA ANA', 'PHOENIX',
#        'MINNEAPOLIS', 'PORTLAND', 'GEORGIA', 'MSA', 'HERNDON', 'SUITE 420',
#        'LAFAYETTE', 'SAN LEANDRO', 'MANTECA', 'METRO', 'BALTIMORE COUNTY',
#        'UNIT C', 'SEBRING', 'SOUTHFIELD', 'WICKLIFFE', 'DENVER CO 80206',
#        'SWANSEA', 'MO-KS', 'ST. CROIX', 'ALBANY', 'W. COVINA',
#        'PORTSMOUTH', 'FARMINGTON )', 'UPPER MARLBORO', 'TRENTON AND EWING',
#        'ST LOUIS', 'SUNNYVALE', 'SOMERVILLE', 'S.W.', 'EL PASO',
#        'CUMBERLAND COUNTY', 'THAILAND', '6TH FLOOR', 'ORANGE', 'PW'], dtype=object)

# %%
val = ['TX', 'MA', 'MI', 'CA', 'VA', 'NJ', 'NY', 'PA', 'FL', 'MN', 'IL',
       'MD', 'CT', 'WA', 'IA', 'CO', 'AZ', 'GA', 'OK', 'LA', 'WI', 'ND',
       'UT', 'IN', 'OH', 'KY', 'NC', 'NH', 'MO', 'TN', 'ID', 'VT', 'DC',
       'SD', 'AL', 'OR', 'AR', 'NM', 'SC', 'NE', 'DE', 'WY', 'HI', 'KS',
       'WV', 'ME', 'RI', 'NV', 'MS', 'AK','MT', 'PR', 'GU', 'VI',  'MP', 'AS']

data['WORKSITE_STATE'] = [
    i if i in val else np.nan for i in data['WORKSITE_STATE']
]

# %%
data.WORKSITE_STATE.unique()
# Out:
# array(['CA', 'NY', 'MS', 'PR', 'PA', 'OH', 'OK', 'OR', 'MD', 'DE', 'FL',
#        'TX', 'VA', 'MA', 'IL', 'IA', 'NJ', 'CO', 'MO', 'MN', 'NC', 'UT',
#        'AK', 'VT', 'MI', 'CT', 'WI', 'KS', 'NE', 'WA', 'GA', 'TN', 'WV',
#        'DC', 'AZ', 'KY', 'AL', 'SC', 'LA', 'IN', 'NH', 'GU', 'NM', 'ID',
#        'AR', 'ND', 'ME', nan, 'HI', 'SD', 'RI', 'NV', 'MT', 'WY', 'VI',
#        'AS', 'MP'], dtype=object)

# %%
len(data.WORKSITE_STATE.unique())
# Out:
# 57

# %%
data.WORKSITE_STATE.isnull().sum()
# Out:
# 695662

# %%
data['CASE_SUBMITTED'] = [
    str(i)[:4] if i else np.nan for i in data['CASE_SUBMITTED']
]

# %%
data.CASE_SUBMITTED.unique()
# Out:
# array(['nan', '2002', '2003', '2004', '2001', '2006', '2020', '2007',
#        '2005', '2008', '2015', '2014', '2013', '2012', '2010', '2011',
#        '2016', '2009', '2017', '2000'], dtype=object)

# %%
data[data.CASE_SUBMITTED == 'nan'].count()
# Out:
# CASE_STATUS             493149
# CASE_SUBMITTED          493149
# EMPLOYER_CITY           492660
# EMPLOYER_POSTAL_CODE    493149
# EMPLOYER_STATE          492193
# WORKSITE_CITY           492420
# WORKSITE_POSTAL_CODE    493149
# WORKSITE_STATE          490169
# dtype: int64

# %%
ndata = data[['CASE_STATUS', 'CASE_SUBMITTED', 'EMPLOYER_STATE', 'WORKSITE_STATE']]

# %%
ndata.head()
# Out:
#   CASE_STATUS CASE_SUBMITTED EMPLOYER_STATE WORKSITE_STATE
# 0   CERTIFIED            nan             CA             CA
# 1   CERTIFIED            nan             CA             CA
# 2   CERTIFIED            nan             CA             CA
# 3   CERTIFIED            nan             PA             CA
# 4   CERTIFIED            nan             PA             CA

# %%
ndata.to_csv('clean/location_state.csv', index = False, encoding ='utf-8')
