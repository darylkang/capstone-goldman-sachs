# %%
import pandas as pd
from ar import *
from ar_val import *

% matplotlib inline
matplotlib.rcParams['figure.figsize'] = 12, 4
matplotlib.rcParams['figure.dpi'] = 300

# %%
data = pd.read_csv('post2009_naics.csv', parse_dates=['CASE_SUBMITTED'])

# %%
autoplot(data, biweeks=39, title='Forecast of Demand for H-1B Visas')

# %%
data_01 = data[(data['CASE_SUBMITTED'] >= '2009-01-01') & (data['CASE_SUBMITTED'] < '2013-01-01')]

# %%
autoplot_val(data_01, title='Forecast of Demand for H-1B Visas', ylim=(-0.1e5, 1.1e5))
# Out:
# RMSE: 9033.924
# MAPE:   21.684

# %%
data_02 = data[(data['CASE_SUBMITTED'] >= '2010-01-01') & (data['CASE_SUBMITTED'] < '2014-01-01')]

# %%
autoplot_val(data_02, title='Forecast of Demand for H-1B Visas', ylim=(-0.1e5, 1.1e5))
# Out:
# RMSE: 16650.514
# MAPE:   95.192

# %%
data_03 = data[(data['CASE_SUBMITTED'] >= '2011-01-01') & (data['CASE_SUBMITTED'] < '2015-01-01')]

# %%
autoplot_val(data_03, title='Forecast of Demand for H-1B Visas', ylim=(-0.1e5, 2.1e5))
# Out:
# RMSE: 10670.034
# MAPE:   18.914

# %%
data_04 = data[(data['CASE_SUBMITTED'] >= '2012-01-01') & (data['CASE_SUBMITTED'] < '2016-01-01')]

# %%
autoplot_val(data_04, title='Forecast of Demand for H-1B Visas', ylim=(-0.1e5, 2.1e5))
# Out:
# RMSE: 12328.164
# MAPE:   20.208

# %%
data_05 = data[(data['CASE_SUBMITTED'] >= '2013-01-01') & (data['CASE_SUBMITTED'] < '2017-01-01')]

# %%
autoplot_val(data_05, title='Forecast of Demand for H-1B Visas', ylim=(-0.1e5, 2.1e5))
# Out:
# RMSE: 10910.830
# MAPE:   22.338

# %%
data_06 = data[(data['CASE_SUBMITTED'] >= '2009-01-01') & (data['CASE_SUBMITTED'] < '2017-01-01')]

# %%
autoplot_val(data_06, title='Forecast of Demand for H-1B Visas', ylim=(-0.1e5, 2.1e5))
# Out:
# RMSE: 12038.914
# MAPE:   22.753
