# %%
import pandas as pd
from ar import *
from ar_val import *

% matplotlib inline
matplotlib.rcParams['figure.figsize'] = 12, 4
matplotlib.rcParams['figure.dpi'] = 300

# %%
data = pd.read_csv('post2009_naics.csv', parse_dates=['CASE_SUBMITTED'])

# %%
autoplot(data, biweeks=39, title='Forecast of Demand for H-1B Visas')

# %%
data_01 = data[(data['CASE_SUBMITTED'] >= '2009-01-01') & (data['CASE_SUBMITTED'] < '2013-01-01')]

# %%
autoplot_val(data_01, title='Cross-Validation for 2009–2012', ylim=(-0.1e5, 1.1e5))
# Out:
# RMSE:  9220  — Root-Mean-Square Error
# MAPE:  22.6% — Mean Absolute Percentage Error
# SE:    16.6% — Standard (Absolute Percentage) Error
#
# 75% Confidence Interval
# Upper Limit:  41.7%
# Lower Limit:   3.5%

# %%
data_02 = data[(data['CASE_SUBMITTED'] >= '2010-01-01') & (data['CASE_SUBMITTED'] < '2014-01-01')]

# %%
autoplot_val(data_02, title='Cross-Validation for 2010–2013', ylim=(-0.1e5, 1.1e5))
# Out:
# RMSE: 16994  — Root-Mean-Square Error
# MAPE:  99.2% — Mean Absolute Percentage Error
# SE:   285.2% — Standard (Absolute Percentage) Error
#
# 75% Confidence Interval
# Upper Limit: 100.0%
# Lower Limit:   0.0%

# %%
data_03 = data[(data['CASE_SUBMITTED'] >= '2011-01-01') & (data['CASE_SUBMITTED'] < '2015-01-01')]

# %%
autoplot_val(data_03, title='Cross-Validation for 2011–2014', ylim=(-0.1e5, 2.1e5))
# Out:
# RMSE: 10890  — Root-Mean-Square Error
# MAPE:  19.7% — Mean Absolute Percentage Error
# SE:    13.5% — Standard (Absolute Percentage) Error
#
# 75% Confidence Interval
# Upper Limit:  35.2%
# Lower Limit:   4.2%

# %%
data_04 = data[(data['CASE_SUBMITTED'] >= '2012-01-01') & (data['CASE_SUBMITTED'] < '2016-01-01')]

# %%
autoplot_val(data_04, title='Cross-Validation for 2012–2015', ylim=(-0.1e5, 2.1e5))
# Out:
# RMSE: 12582  — Root-Mean-Square Error
# MAPE:  21.1% — Mean Absolute Percentage Error
# SE:    11.4% — Standard (Absolute Percentage) Error
#
# 75% Confidence Interval
# Upper Limit:  34.1%
# Lower Limit:   8.0%

# %%
data_05 = data[(data['CASE_SUBMITTED'] >= '2013-01-01') & (data['CASE_SUBMITTED'] < '2017-01-01')]

# %%
autoplot_val(data_05, title='Cross-Validation for 2013–2016', ylim=(-0.1e5, 2.1e5))
# Out:
# RMSE: 11136  — Root-Mean-Square Error
# MAPE:  23.3% — Mean Absolute Percentage Error
# SE:    19.0% — Standard (Absolute Percentage) Error
#
# 75% Confidence Interval
# Upper Limit:  45.1%
# Lower Limit:   1.4%

# %%
data_06 = data[(data['CASE_SUBMITTED'] >= '2009-01-01') & (data['CASE_SUBMITTED'] < '2017-01-01')]

# %%
autoplot_val(data_06, title='Cross-Validation for 2009–2016', ylim=(-0.1e5, 2.1e5))
# Out:
# RMSE: 12287  — Root-Mean-Square Error
# MAPE:  23.7% — Mean Absolute Percentage Error
# SE:    20.4% — Standard (Absolute Percentage) Error
#
# 75% Confidence Interval
# Upper Limit:  47.2%
# Lower Limit:   0.2%
