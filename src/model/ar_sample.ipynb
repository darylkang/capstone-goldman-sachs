# %%
import pandas as pd
from ar import *

% matplotlib inline
matplotlib.rcParams['figure.figsize'] = 12, 4
matplotlib.rcParams['figure.dpi'] = 300

# %%
data = pd.read_csv('post2009_naics.csv')

# %%
autoplot(data)
